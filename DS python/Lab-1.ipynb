# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello world")
b="KLH BOWRAMPET"
print(b)
#slicing
print(b[2:5])
print(b[-10:-4])
#String methods
print(b.capitalize())
print(b.casefold())
#print(b.center(60,*))
print(b.count("B"))
print(b.lower())
print(b.find("B"))
print(b.islower())
print(b.isupper())
print(b.replace("B","b"))
print(b.join("KLH"))
print(b.split(" "))
print(b.swapcase())
print(b.zfill(20))
# Out:
# Hello world
# KLH BOWRAMPET
# H B
#  BOWRA
# Klh bowrampet
# klh bowrampet
# 1
# klh bowrampet
# 4
# False
# True
# KLH bOWRAMPET
# KKLH BOWRAMPETLKLH BOWRAMPETH
# ['KLH', 'BOWRAMPET']
# klh bowrampet
# 0000000KLH BOWRAMPET

# %%
txt="Hello, My name is {fname}, I am {age}".format(fname="John",age=36)
print(txt)
# Out:
# Hello, My name is John, I am 36

# %%
name = "KLH"
print(format(name))
print("{:<10}".format(name))
# Out:
# KLH
